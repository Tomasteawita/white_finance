# %%
import pandas as pd
import os

# %%
# %ls ../data/
# Out:
#  cartera_problemas.csv
#  cuenta_corriente_dolares_cable_historico.csv*
#  cuenta_corriente_dolares_historico.csv*
#  cuenta_corriente_historico.csv*
#  cuenta_corriente_mep_ccl_historico.csv
#  cuenta_corriente_pesos_dolarizada_historico.csv
#  cuenta_corriente_unificada_historico.csv
#  profit.csv*
#  ratio_mep_ccl.csv
#  tipo_cambio_ggal.csv
#  tipo_cambio_ggal_mep.csv
# 'Transferencias Bull Market.csv'

# %%
df = pd.read_csv('../data/cuenta_corriente_historico.csv', sep=',')

df_filtrado = df[['Liquida', 'Comprobante', 'Importe']]

# Filtrar por los valores específicos en la columna "Comprobante"
df_filtrado = df_filtrado[df_filtrado['Comprobante'].isin(['RECIBO DE COBRO', 'ORDEN DE PAGO'])]

# Crear el directorio si no existe
os.makedirs('../data', exist_ok=True)

# Exportar a CSV
df_filtrado.to_csv('../data/Transferencias Bull Market.csv', sep=',', index=False)

print(f"Archivo exportado exitosamente: {len(df_filtrado)} registros")
# Out:
# Archivo exportado exitosamente: 79 registros

# %%
# Leer el archivo (ajusta la ruta según tu archivo)
# df = pd.read_csv('ruta/a/tu/archivo.csv')
# o
# df = pd.read_excel('ruta/a/tu/archivo.xlsx')

# Seleccionar solo las columnas necesarias
