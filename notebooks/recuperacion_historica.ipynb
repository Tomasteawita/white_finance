# %%
import pandas as pd

# %%
# %ls ../data/cuentas_corrientes/
# Out:
# 'clean_cuenta corriente historico dolares cable.csv'
# 'clean_cuenta corriente historico dolar mep.csv'
# 'clean_Cuenta corriente historico en pesos.csv'
# 'cuenta corriente historico dolares cable.csv'*
# 'cuenta corriente historico dolares cable.PDF'*
# 'cuenta corriente historico dolar mep.csv'*
# 'cuenta corriente historico dolar mep.PDF'*
# 'Cuenta corriente historico en pesos.csv'*
# 'Cuenta corriente historico en pesos.PDF'*
#  saldo_comparison.csv

# %%
cuentas_corrientes_historicas_previas = [
    'clean_cuenta corriente historico dolares cable.csv',
    'clean_cuenta corriente historico dolar mep.csv',
    'clean_Cuenta corriente historico en pesos.csv'
]

cuentas_corrientes_historicas_actuales = [
    'cuenta_corriente_dolares_cable_historico.csv',
    'cuenta_corriente_dolares_historico.csv',
    'cuenta_corriente_historico.csv'
]
