# %%
import pandas as pd

# %%
# Read the HTML file
data = pd.read_html('../table_data.html')
# Convert the data to a DataFrame
df = pd.DataFrame(data[0])

# %%
df
# Out:
#       Unnamed: 0                                  Producto      Cantidad  \
# 0       Acciones                                  Acciones      Acciones
# 1            NaN                AUSO  *  AUTOPISTA DEL SOL          4400
# 2            NaN                   CEPU  *  CENTRAL PUERTO          5400
# 3            NaN           DGCU2  *  DISTRIB DE GAS CUYANA          6700
# 4            NaN                         FIPL  *  FIPLASTO         28500
# 5            NaN         GGAL  *  GRUPO FINANCIERO GALICIA          2100
# 6            NaN                           MIRG  *  MIRGOR           400
# 7            NaN                    PAMP  *  PAMPA ENERGIA          3200
# 8            NaN               TECO2  *  TELECOM ARGENTINA          4800
# 9            NaN                        TRAN  *  TRANSENER          5300
# 10       Cedears                                   Cedears       Cedears
# 11           NaN  PAAS  *  CEDEAR PAN AMERICAN SILVER CORP          1000
# ...
