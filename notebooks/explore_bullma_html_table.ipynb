# %%
import pandas as pd

# %%
# Read the HTML file
data = pd.read_html('../data/bullma_portfolio_2024-09-13.html')
# Convert the data to a DataFrame
df = pd.DataFrame(data[0])

# %%
df
# Out:
#       Unnamed: 0                                  Producto      Cantidad  \
# 0       Acciones                                  Acciones      Acciones
# 1            NaN                AUSO  *  AUTOPISTA DEL SOL          7000
# 2            NaN                   CEPU  *  CENTRAL PUERTO          5900
# 3            NaN           DGCU2  *  DISTRIB DE GAS CUYANA         10200
# 4            NaN                         FIPL  *  FIPLASTO         43500
# 5            NaN         GGAL  *  GRUPO FINANCIERO GALICIA          2800
# 6            NaN                           MIRG  *  MIRGOR           700
# 7            NaN                    PAMP  *  PAMPA ENERGIA          4900
# 8            NaN               TECO2  *  TELECOM ARGENTINA          7100
# 9            NaN                        TRAN  *  TRANSENER          5300
# 10       Cedears                                   Cedears       Cedears
# 11           NaN  PAAS  *  CEDEAR PAN AMERICAN SILVER CORP          1700
# ...
